# %%
# Import libraries
import pandas as pd
from src.models import load_model, predict

# %%
# Load test data
test_data = pd.read_csv("data/processed/test_data.csv")
X_test = test_data.drop(columns=['target'])
y_test = test_data['target']

# %%
# Load the trained model
best_model = joblib.load("models/trained/best_model.pkl")

# %%
# Make predictions
y_pred = best_model.predict(X_test)

# %%
# Save predictions
predictions = pd.DataFrame({'actual': y_test, 'predicted': y_pred})
predictions.to_csv("reports/final_project/predictions.csv", index=False)
print("Predictions saved to 'reports/final_project/predictions.csv'.")
